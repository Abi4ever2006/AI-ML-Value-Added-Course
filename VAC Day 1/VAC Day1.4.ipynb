# %%
import spacy
nlp=spacy.load('en_core_web_sm')
doc=nlp(u'Tesla is looking at buying U.S. startup for $6 million')
for token in doc:
  print(token.text,token.pos_,token.dep_)
# Out:
# Tesla PROPN nsubj
# is AUX aux
# looking VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.S. PROPN compound
# startup NOUN dobj
# for ADP prep
# $ SYM quantmod
# 6 NUM compound
# million NUM pobj

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x1eaf42d96a0>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x1eaf42d9f40>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x1eaf41d6820>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x1eaf44f0380>),
#  ('lemmatizer', <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x1eaf44d0d80>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x1eaf41d6ac0>)]

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
doc2=nlp(u"Tesla isn't  looking into startups anymore.")
for token in doc2:
  print(token.text,token.pos_,token.dep_)
# Out:
# Tesla PROPN nsubj
# is AUX aux
# n't PART neg
#   SPACE dep
# looking VERB ROOT
# into ADP prep
# startups NOUN pobj
# anymore ADV advmod
# . PUNCT punct

# %%
doc2
# Out:
# Tesla isn't  looking into startups anymore.

# %%
doc2[0]
# Out:
# Tesla

# %%
type(doc2)
# Out:
# spacy.tokens.doc.Doc

# %%
doc2[0].pos_
# Out:
# 'PROPN'

# %%
doc2[0].dep_
# Out:
# 'nsubj'

# %%
spacy.explain('PROPN')
# Out:
# 'proper noun'

# %%
spacy.explain('nsubj')
# Out:
# 'nominal subject'

# %%
print(doc2[4].text)
print(doc2[4].lemma)
print(doc2[4].pos_)
print(doc2[4].tag_ + ' / ' + spacy.explain(doc2[4].tag_))
print(doc2[0].text+': '+doc2[0].shape_)
print(doc[5].text+' : '+doc[5].shape_)

print(doc2[0].is_alpha)
print(doc2[0].is_stop)
# Out:
# looking
# 16096726548953279178
# VERB
# VBG / verb, gerund or present participle
# Tesla: Xxxxx
# U.S. : X.X.
# True
# False

# %%
doc3=nlp(u'Although commonly attributed to John Lennon from his song "Beautiful Boy", \ the phrase "Life is what happens to us while we are making other plans" was written by \ cartoonist Allen Saunders and published in Reader\'s Digest in 1957, when Lennon was 17.')
life_quote=doc3[16:30]
print(life_quote)
# Out:
# phrase "Life is what happens to us while we are making other plans

# %%
type(life_quote)
# Out:
# spacy.tokens.span.Span

# %%
doc4=nlp(u'This is the first sentence. This is another sentence. This is the last sentence.')
for sent in doc4.sents:
  print(sent)
# Out:
# This is the first sentence.
# This is another sentence.
# This is the last sentence.

# %%
doc4[6].is_sent_start
# Out:
# True
