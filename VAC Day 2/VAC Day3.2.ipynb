# %%
import numpy as np

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\24it001\appdata\roaming\python\python39\site-packages (from scikit-learn) (1.24.4)
# Requirement already satisfied: scipy>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)

# %%
from sklearn.datasets import load_iris
iris=load_iris()
type(iris)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13088\2478974212.py in <module>
# ----> 1 from sklearn.datasets import load_iris
#       2 iris=load_iris()
#       3 type(iris)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\__init__.py in <module>
#      80     from . import _distributor_init  # noqa: F401
#      81     from . import __check_build  # noqa: F401
# ---> 82     from .base import clone
#      83     from .utils._show_versions import show_versions
#      84
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in <module>
#      15 from . import __version__
#      16 from ._config import get_config
# ---> 17 from .utils import _IS_32BIT
#      18 from .utils._tags import (
#      19     _DEFAULT_TAGS,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\__init__.py in <module>
#      19 import warnings
#      20 import numpy as np
# ---> 21 from scipy.sparse import issparse
#      22
#      23 from .murmurhash import murmurhash3_32
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py in <module>
#      88     if _key.startswith('_'):
#      89         continue
# ---> 90     _fun = getattr(np, _key)
#      91     if isinstance(_fun, _types.ModuleType):
#      92         continue
#
# ~\AppData\Roaming\Python\Python39\site-packages\numpy\__init__.py in __getattr__(attr)
#     395     import os
#     396     use_hugepage = os.environ.get("NUMPY_MADVISE_HUGEPAGE", None)
# --> 397     if sys.platform == "linux" and use_hugepage is None:
#     398         # If there is an issue with parsing the kernel version,
#     399         # set use_hugepages to 0. Usage of LooseVersion will handle
#
# ModuleNotFoundError: No module named 'numpy.char'

# %%
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df.head()

# %%
print(iris.DESCR)

# %%
X=iris.data
X

# %%
y=iris.target
y

# %%
from tensorflow.keras.utils import to_categorical

# %%
from tensorflow.keras.utils import to_categorical

# %%
y=iris.target
y=to_categorical(y)
y.shape

# %%
# !pip uninstall tensorflow -y
# !pip uninstall keras -y
# !pip install --upgrade pip
# !pip install tensorflow

# %%
import sys
print(sys.executable)

# %%
# !C:\ProgramData\Anaconda3\python.exe -m pip install tensorflow

# %%
from tensorflow.keras.utils import to_categorical

# %%
# !pip install keras
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras in c:\users\24it001\appdata\roaming\python\python39\site-packages (3.10.0)
# Requirement already satisfied: absl-py in c:\users\24it001\appdata\roaming\python\python39\site-packages (from keras) (2.3.1)
# Requirement already satisfied: numpy in c:\users\24it001\appdata\roaming\python\python39\site-packages (from keras) (1.24.4)
# Requirement already satisfied: rich in c:\users\24it001\appdata\roaming\python\python39\site-packages (from keras) (14.3.3)
# Requirement already satisfied: namex in c:\users\24it001\appdata\roaming\python\python39\site-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in c:\users\24it001\appdata\roaming\python\python39\site-packages (from keras) (3.14.0)
# Requirement already satisfied: optree in c:\users\24it001\appdata\roaming\python\python39\site-packages (from keras) (0.19.0)
# Requirement already satisfied: ml-dtypes in c:\users\24it001\appdata\roaming\python\python39\site-packages (from keras) (0.5.4)
# Requirement already satisfied: packaging in c:\users\24it001\appdata\roaming\python\python39\site-packages (from keras) (26.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\24it001\appdata\roaming\python\python39\site-packages (from optree->keras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\24it001\appdata\roaming\python\python39\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\24it001\appdata\roaming\python\python39\site-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\24it001\appdata\roaming\python\python39\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
from tensorflow.keras.utils import to_categorical

# %%
y=iris.target
y=to_categorical(y)
y.shape

# %%
from keras.model import load_model
