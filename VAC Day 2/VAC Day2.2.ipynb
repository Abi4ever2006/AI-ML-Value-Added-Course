# %%
import spacy
nlp=spacy.load('en_core_web_sm')

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'before', 'hereafter', 'anyone', 'the', '‘ve', 'could', 'except', 'seems', '’m', 'seeming', '‘re', 'onto', 'my', 'you', 'otherwise', 'anywhere', 'sometimes', 'will', 'former', "'re", 'here', 'serious', 'make', 'its', 'our', 'meanwhile', '‘s', 'whereupon', 'formerly', 'anyway', 'thereby', '’s', 'every', 'off', 'fifty', 'those', 'where', 'as', 'now', 'too', 'have', 'give', 'much', 'besides', 'empty', 'about', 'unless', 'any', 'anyhow', 'not', 'noone', 'amongst', 'often', 'through', 'whose', 'everyone', 'along', 'whatever', 'becoming', '’d', 'whence', 'most', 'wherever', 'amount', 'than', "'d", 'neither', 'has', 'whereby', 'why', 'everywhere', 'cannot', 'becomes', 'among', 'one', 'few', 'put', 'themselves', 'never', 'be', 'per', 'three', 'toward', 'nine', 'somehow', 'we', 'hereupon', '‘ll', 'during', 'third', 'twelve', 'rather', 'so', 'please', 'how', '‘d', 'mine', 'six', 'other', 'whole', 'and', 'sometime', 'her', 'thence', 'together', 'around', 'eight', 'must', 'front', 'first', 'whereafter', 'hence', "'m", 'least', 'might', 'us', 'yours', 'or', 'though', 'elsewhere', 'full', 'should', 'indeed', 'am', 'eleven', 'whereas', 'nobody', 'had', 'what', 'always', 'he', 'nowhere', 'beside', 'also', 'in', 'does', 'further', 'whom', 'another', 'nevertheless', 'still', 'all', 'however', 'whenever', 'that', 'namely', 'fifteen', 're', 'within', 'there', '’ve', 'just', "'s", '’re', 'afterwards', 'top', 'n’t', 'because', 'own', 'them', 'doing', 'to', 'already', 'see', 'no', 'when', 'hers', 'whoever', 'out', 'this', 'call', 'did', 'myself', 'of', 'really', 'moreover', 'keep', 'without', 'these', 'over', 'less', 'forty', 'part', 'enough', 'below', 'well', 'after', 'bottom', 'thru', 'each', 'yourselves', 'by', 'on', 'under', 'become', 'such', 'are', 'it', 'been', 'therein', 'with', 'side', 'ours', 'whither', 'him', 'many', 'twenty', 'therefore', 'wherein', 'latterly', 'used', 'various', 'beyond', 'but', 'move', 'from', 'ten', 'everything', 'thus', 'is', 'quite', 'although', 'regarding', 'until', 'towards', 'was', 'became', 'himself', 'ca', 'since', 'ever', 'else', 'their', 'can', 'get', 'thereafter', 'yet', 'mostly', 'latter', 'only', 'me', 'alone', 'perhaps', 'she', 'an', 'who', 'using', 'some', 'above', 'thereupon', 'name', 'at', 'into', 'across', 'made', 'herself', 'seem', 'due', 'for', 'nothing', 'several', 'throughout', 'someone', 'anything', 'down', "n't", 'more', 'almost', 'then', 'his', 'ourselves', 'n‘t', 'were', 'against', 'if', 'between', 'even', 'would', 'done', 'hereby', 'sixty', 'say', "'ll", 'behind', 'your', 'somewhere', 'five', 'four', 'may', 'beforehand', 'itself', 'i', 'nor', '’ll', 'do', 'herein', 'they', '‘m', 'back', 'again', 'hundred', 'something', 'both', 'go', 'show', 'a', 'same', 'being', 'upon', 'yourself', 'very', 'whether', 'seemed', 'two', 'via', 'others', 'none', "'ve", 'next', 'once', 'while', 'last', 'take', 'which', 'either', 'up'}

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
nlp.vocab['myself'].is_stop
# Out:
# True

# %%
nlp.vocab['mystery'].is_stop
# Out:
# False

# %%
nlp.Defaults.stop_words.add('btw')
nlp.vocab['btw'].is_stop = True
len(nlp.Defaults.stop_words)
# Out:
# 327

# %%
nlp.vocab['btw'].is_stop
# Out:
# True
